# %%
import numpy as np
import cv2
import msgpack as mp
import msgpack_numpy as mpn
import matplotlib.pyplot as plt

# %%
_pth = r"C:\Users\CMC\Documents\openposelibs\pose\armbo\recording_programs\test_data\single_cam_oct_21\sk13_forward_t0\webcam_color.msgpack"
with open(_pth, "rb") as f:
    data = mp.Unpacker(f, object_hook=mpn.decode)
    for frame in data:
        break
plt.imshow(frame, cmap="gray")

# %%
# binarise the image
th, im_gray_th_otsu = cv2.threshold(frame, 128, 192, cv2.THRESH_OTSU)
plt.imshow(im_gray_th_otsu, cmap="gray")

# %%
# insert contour tracing algorithm here

def get_contours(img):
    # find contours in the image
    contours, hierarchy = cv2.findContours(img, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    return contours, hierarchy

# %%
contours, hierarchy = get_contours(im_gray_th_otsu)

# %%
len(contours)
# Out:
# 875
